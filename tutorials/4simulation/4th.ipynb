# %%
# import PyXplore package
from PyXplore import WPEM
import pandas as pd
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2025-07-21 11:36:04  | Have a great day.
# ...

# %% [markdown]
# > Save the `.cif` file in the root directory and generate its powder diffraction pattern.

# %%
_,_,_ = WPEM.XRDSimulation(filepath='CONTCAR99.cif',two_theta_range=(10, 120, 0.01),bacI=True,GrainSize=3,orientation=[-0.2, 0.3],thermo_vib=0.2,zero_shift=0.01)
# Out:
# cif file parse completed
# cif file parse failed with error
# Please replace another cif file, or enter manually the essential params!
# Please input point_group singal (i.e., F): P
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 195 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Tetragonal  |  The initial lattice constants : 7.978884 7.978884 8.063809 90.0 90.0 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Ru', 'O', 1.9947]
# XRD simulation process of WPEM is completed !
