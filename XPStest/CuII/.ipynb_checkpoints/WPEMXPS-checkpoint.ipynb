# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-02-17 13:23:40  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,segement=[[910,925],[947,952],[958,960],[966,970]],bac_num=120,Model='XPS',noise = 0.05,bac_var_type='multivariate gaussian')

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM

var = 0.1
AtomIdentifier = [['CuII','2p3/2',933.9,],['CuII','2p1/2',953,],]
satellitePeaks = [['CuII', '2p3/2',941,],['CuII','2p3/2',943],['CuII','2p1/2',962.5,],]
# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, satellitePeaks,no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.80,iter_max = 20, InitializationEpoch=0,asy_C=0.08,s_energy=[[950,960],],)
# Out:
# Started at Sat Feb 17 21:39:54 2024
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#  15%|██████▌                                     | 3/20 [00:00<00:00, 29.16it/s]
# WPEM 0-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.567
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6582086224323039
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.94, [2, 1, 1.5]], ['CuII', '2p1/2', 953.301, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.05], ['CuII', '2p3/2', 943.075], ['CuII', '2p1/2', 962.419]]]
# Rp:44.067 | Rwp:51.156 | Rsquare:286.448
#
#
# WPEM 1-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.463
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6959534702211783
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.955, [2, 1, 1.5]], ['CuII', '2p1/2', 953.003, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.058], ['CuII', '2p3/2', 943.103], ['CuII', '2p1/2', 962.382]]]
# Rp:45.294 | Rwp:54.123 | Rsquare:310.471
#
#
# WPEM 2-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.468
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.7027447658118082
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.952, [2, 1, 1.5]], ['CuII', '2p1/2', 953.016, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.027], ['CuII', '2p3/2', 943.06], ['CuII', '2p1/2', 962.363]]]
# Rp:45.742 | Rwp:52.286 | Rsquare:296.212
#
#
# WPEM 3-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.473
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.651139368761606
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.954, [2, 1, 1.5]], ['CuII', '2p1/2', 953.033, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.002], ['CuII', '2p3/2', 943.048], ['CuII', '2p1/2', 962.365]]]
# Rp:46.240 | Rwp:52.436 | Rsquare:299.825
#
#
# WPEM 4-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.476
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6125521555808726
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.963, [2, 1, 1.5]], ['CuII', '2p1/2', 953.05, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.99], ['CuII', '2p3/2', 943.056], ['CuII', '2p1/2', 962.37]]]
# Rp:46.532 | Rwp:52.667 | Rsquare:303.043
#
#
# WPEM 5-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.481
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5941003321921068
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.974, [2, 1, 1.5]], ['CuII', '2p1/2', 953.076, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.98], ['CuII', '2p3/2', 943.068], ['CuII', '2p1/2', 962.371]]]
# Rp:46.687 | Rwp:52.799 | Rsquare:304.766
#
#
# WPEM 6-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.499
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.585918598961962
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.983, [2, 1, 1.5]], ['CuII', '2p1/2', 953.139, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.972], ['CuII', '2p3/2', 943.077], ['CuII', '2p1/2', 962.371]]]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 37.39it/s]
# Rp:46.797 | Rwp:52.916 | Rsquare:306.043
#
#
# WPEM 7-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.551
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.582549685725932
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.988, [2, 1, 1.5]], ['CuII', '2p1/2', 953.301, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.965], ['CuII', '2p3/2', 943.082], ['CuII', '2p1/2', 962.369]]]
# Rp:46.925 | Rwp:53.137 | Rsquare:308.047
#
#
# WPEM 8-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.491
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5824099837998465
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.994, [2, 1, 1.5]], ['CuII', '2p1/2', 953.126, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.959], ['CuII', '2p3/2', 943.085], ['CuII', '2p1/2', 962.366]]]
# Rp:46.860 | Rwp:52.929 | Rsquare:306.425
#
#
# WPEM 9-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.49
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5801600236226649
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.997, [2, 1, 1.5]], ['CuII', '2p1/2', 953.126, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.954], ['CuII', '2p3/2', 943.084], ['CuII', '2p1/2', 962.366]]]
# Rp:46.890 | Rwp:52.946 | Rsquare:306.726
#
#
# WPEM 10-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5790093189750529
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.0, [2, 1, 1.5]], ['CuII', '2p1/2', 953.127, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.95], ['CuII', '2p3/2', 943.083], ['CuII', '2p1/2', 962.366]]]
#  65%|███████████████████████████▉               | 13/20 [00:00<00:00, 39.66it/s]
# Rp:46.912 | Rwp:52.962 | Rsquare:306.965
#
#
# WPEM 11-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5785402027996316
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.002, [2, 1, 1.5]], ['CuII', '2p1/2', 953.128, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.946], ['CuII', '2p3/2', 943.081], ['CuII', '2p1/2', 962.366]]]
# Rp:46.930 | Rwp:52.978 | Rsquare:307.190
#
#
# WPEM 12-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.488
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5784240691017501
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.005, [2, 1, 1.5]], ['CuII', '2p1/2', 953.129, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.943], ['CuII', '2p3/2', 943.079], ['CuII', '2p1/2', 962.366]]]
# Rp:46.945 | Rwp:52.988 | Rsquare:307.359
#
#
# WPEM 13-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.488
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.578491618159793
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.007, [2, 1, 1.5]], ['CuII', '2p1/2', 953.13, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.94], ['CuII', '2p3/2', 943.076], ['CuII', '2p1/2', 962.365]]]
# Rp:46.959 | Rwp:53.001 | Rsquare:307.534
#
#
# WPEM 14-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5786975676469226
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.008, [2, 1, 1.5]], ['CuII', '2p1/2', 953.134, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.937], ['CuII', '2p3/2', 943.074], ['CuII', '2p1/2', 962.364]]]
# Rp:46.975 | Rwp:53.015 | Rsquare:307.716
#
#
# WPEM 15-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5790154545128763
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.01, [2, 1, 1.5]], ['CuII', '2p1/2', 953.136, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.935], ['CuII', '2p3/2', 943.071], ['CuII', '2p1/2', 962.363]]]
# Rp:46.988 | Rwp:53.025 | Rsquare:307.854
#
#
# WPEM 16-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5793978997604875
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.012, [2, 1, 1.5]], ['CuII', '2p1/2', 953.138, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.933], ['CuII', '2p3/2', 943.069], ['CuII', '2p1/2', 962.362]]]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 39.52it/s]
# Rp:46.999 | Rwp:53.033 | Rsquare:307.979
#
#
# WPEM 17-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.489
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5798334384825399
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.014, [2, 1, 1.5]], ['CuII', '2p1/2', 953.14, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.93], ['CuII', '2p3/2', 943.067], ['CuII', '2p1/2', 962.36]]]
# Rp:47.010 | Rwp:53.041 | Rsquare:308.091
#
#
# WPEM 18-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.49
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5803124591556678
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.015, [2, 1, 1.5]], ['CuII', '2p1/2', 953.144, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.929], ['CuII', '2p3/2', 943.065], ['CuII', '2p1/2', 962.358]]]
# Rp:47.022 | Rwp:53.051 | Rsquare:308.220
#
#
# WPEM 19-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.49
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5808395741364707
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.017, [2, 1, 1.5]], ['CuII', '2p1/2', 953.146, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.927], ['CuII', '2p3/2', 943.063], ['CuII', '2p1/2', 962.357]]]
# Rp:47.031 | Rwp:53.057 | Rsquare:308.311
#
#
# After update the background :   Rp = 47.031 | Rwp = 53.057 | Rsquare = 308.311
# 20-th iterations, reach the maximum number of iteration steps.
#  Rp: 47.031
# Rwp: 53.057
#
#
# WPEM-XPS program running time :  0 hours 0 minute  4 second
# '0 hours 0 minute  4 second  '
