# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-12-18 10:13:20  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,segement=[[910,925],[947,952],[958,960],[966,970]],bac_num=120,Model='XPS',noise = 0.05,bac_var_type='multivariate gaussian')

# %%
AtomIdentifier = [['CuII','2p3/2',932.9,],['CuII','2p1/2',952.5],]
SatellitePeaks = [['CuII','2p3/2',941,943],['CuII','2p1/2',962.5,]]
# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.90,iter_max = 100, asy_C = 0.,
    )
# Out:
# Started at Wed Nov  8 19:53:43 2023
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#
# WPEM 1-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:8.556 | Rwp:16.296 | Rsquare:35.936
#
#
# WPEM 2-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:8.028 | Rwp:16.383 | Rsquare:33.367
#
#
# Under the central field approximation, the effective charge of Cu is: 25.75
# WPEM 3-th iteration
# ['Cu', '2p3/2', 932.479]
# ['Cu', '2p1/2', 952.401]
# Rp:4.915 | Rwp:8.767 | Rsquare:9.645
#
#
# Under the central field approximation, the effective charge of Cu is: 25.74
# WPEM 4-th iteration
# ['Cu', '2p3/2', 932.483]
# ['Cu', '2p1/2', 952.373]
# Rp:4.773 | Rwp:8.664 | Rsquare:9.461
#
#
# Under the central field approximation, the effective charge of Cu is: 25.73
# WPEM 5-th iteration
# ['Cu', '2p3/2', 932.487]
# ['Cu', '2p1/2', 952.347]
# Rp:4.695 | Rwp:8.656 | Rsquare:9.446
#
#
# Under the central field approximation, the effective charge of Cu is: 25.73
# WPEM 6-th iteration
# ['Cu', '2p3/2', 932.478]
# ['Cu', '2p1/2', 952.338]
# Rp:4.590 | Rwp:8.412 | Rsquare:8.915
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 7-th iteration
# ['Cu', '2p3/2', 932.487]
# ['Cu', '2p1/2', 952.316]
# Rp:4.603 | Rwp:8.576 | Rsquare:9.284
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 8-th iteration
# ['Cu', '2p3/2', 932.483]
# ['Cu', '2p1/2', 952.312]
# Rp:4.558 | Rwp:8.462 | Rsquare:9.041
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 9-th iteration
# ['Cu', '2p3/2', 932.48]
# ['Cu', '2p1/2', 952.309]
# Rp:4.529 | Rwp:8.390 | Rsquare:8.893
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 10-th iteration
# ['Cu', '2p3/2', 932.478]
# ['Cu', '2p1/2', 952.307]
# Rp:4.511 | Rwp:8.344 | Rsquare:8.797
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 11-th iteration
# ['Cu', '2p3/2', 932.477]
# ['Cu', '2p1/2', 952.306]
# Rp:4.499 | Rwp:8.313 | Rsquare:8.734
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 12-th iteration
# ['Cu', '2p3/2', 932.476]
# ['Cu', '2p1/2', 952.305]
# Rp:4.490 | Rwp:8.292 | Rsquare:8.691
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 13-th iteration
# ['Cu', '2p3/2', 932.475]
# ['Cu', '2p1/2', 952.304]
# Rp:4.484 | Rwp:8.277 | Rsquare:8.660
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 14-th iteration
# ['Cu', '2p3/2', 932.475]
# ['Cu', '2p1/2', 952.304]
# Rp:4.479 | Rwp:8.266 | Rsquare:8.638
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 15-th iteration
# ['Cu', '2p3/2', 932.475]
# ['Cu', '2p1/2', 952.304]
# Rp:4.476 | Rwp:8.258 | Rsquare:8.622
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 16-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.304]
# Rp:4.473 | Rwp:8.252 | Rsquare:8.610
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 17-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.471 | Rwp:8.247 | Rsquare:8.600
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 18-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.469 | Rwp:8.244 | Rsquare:8.593
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 19-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.468 | Rwp:8.241 | Rsquare:8.588
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 20-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.467 | Rwp:8.239 | Rsquare:8.583
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 21-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.466 | Rwp:8.237 | Rsquare:8.580
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 22-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.466 | Rwp:8.236 | Rsquare:8.577
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 23-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.465 | Rwp:8.235 | Rsquare:8.575
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 24-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.465 | Rwp:8.234 | Rsquare:8.573
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 25-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.464 | Rwp:8.233 | Rsquare:8.571
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 26-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.464 | Rwp:8.232 | Rsquare:8.570
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 27-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.464 | Rwp:8.232 | Rsquare:8.569
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 28-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.463 | Rwp:8.232 | Rsquare:8.568
#
#
# Under the central field approximation, the effective charge of Cu is: 25.72
# WPEM 29-th iteration
# ['Cu', '2p3/2', 932.474]
# ['Cu', '2p1/2', 952.303]
# Rp:4.463 | Rwp:8.231 | Rsquare:8.568
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 30-th iteration
# ['Cu', '2p3/2', 932.489]
# ['Cu', '2p1/2', 952.287]
# Rp:4.543 | Rwp:8.559 | Rsquare:9.273
#
#
# After update the background :   Rp = 3.516 | Rwp = 8.145 | Rsquare = 8.673
# 30-th iterations, reach the limit of lock_num.
#  Rp: 3.516
# Rwp: 8.145
#
#
# WPEM-XPS program running time :  0 hours 0 minute  4 second
# '0 hours 0 minute  4 second  '
