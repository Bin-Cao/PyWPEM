# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-02-19 12:16:21  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,segement=[[910,925],[947,952],[958,960],[966,970]],bac_num=120,Model='XPS',noise = 0.05,bac_var_type='multivariate gaussian')

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM

var = 0.1
AtomIdentifier = [['CuII','2p3/2',933.9,],['CuII','2p1/2',953,],]
satellitePeaks = [['CuII', '2p3/2',941,],['CuII','2p3/2',943],['CuII','2p1/2',962.5,],]
# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, satellitePeaks,no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.80,iter_max = 20, InitializationEpoch=0,)
# Out:
# Started at Mon Feb 19 12:18:08 2024
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#  15%|██████▌                                     | 3/20 [00:00<00:00, 28.23it/s]
# WPEM 0-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.534
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6197179363527894
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.936, [2, 1, 1.5]], ['CuII', '2p1/2', 953.198, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.056], ['CuII', '2p3/2', 943.042], ['CuII', '2p1/2', 962.415]]]
# Rp:44.945 | Rwp:50.993 | Rsquare:283.723
#
#
# WPEM 1-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.554
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.57508588931546
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.946, [2, 1, 1.5]], ['CuII', '2p1/2', 953.268, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.044], ['CuII', '2p3/2', 943.055], ['CuII', '2p1/2', 962.41]]]
# Rp:45.709 | Rwp:51.885 | Rsquare:294.178
#
#
# WPEM 2-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.569
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5639673906025968
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.954, [2, 1, 1.5]], ['CuII', '2p1/2', 953.322, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.019], ['CuII', '2p3/2', 943.066], ['CuII', '2p1/2', 962.402]]]
# Rp:46.096 | Rwp:52.261 | Rsquare:298.869
#
#
# WPEM 3-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5581209434278086
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.965, [2, 1, 1.5]], ['CuII', '2p1/2', 953.357, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.999], ['CuII', '2p3/2', 943.076], ['CuII', '2p1/2', 962.396]]]
# Rp:46.290 | Rwp:52.413 | Rsquare:300.882
#
#
# WPEM 4-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.581
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.554237262323064
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.974, [2, 1, 1.5]], ['CuII', '2p1/2', 953.378, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.986], ['CuII', '2p3/2', 943.082], ['CuII', '2p1/2', 962.39]]]
# Rp:46.398 | Rwp:52.482 | Rsquare:301.862
#
#
# WPEM 5-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.581
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5516185547251207
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.983, [2, 1, 1.5]], ['CuII', '2p1/2', 953.387, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.976], ['CuII', '2p3/2', 943.085], ['CuII', '2p1/2', 962.386]]]
# Rp:46.468 | Rwp:52.518 | Rsquare:302.411
#
#
# WPEM 6-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.581
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5498519128404127
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.989, [2, 1, 1.5]], ['CuII', '2p1/2', 953.393, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.968], ['CuII', '2p3/2', 943.086], ['CuII', '2p1/2', 962.384]]]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 36.08it/s]
# Rp:46.518 | Rwp:52.544 | Rsquare:302.817
#
#
# WPEM 7-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.58
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5486337639858541
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.994, [2, 1, 1.5]], ['CuII', '2p1/2', 953.395, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.962], ['CuII', '2p3/2', 943.085], ['CuII', '2p1/2', 962.383]]]
# Rp:46.554 | Rwp:52.566 | Rsquare:303.151
#
#
# WPEM 8-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.579
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5477640209183096
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.998, [2, 1, 1.5]], ['CuII', '2p1/2', 953.396, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.957], ['CuII', '2p3/2', 943.084], ['CuII', '2p1/2', 962.382]]]
# Rp:46.582 | Rwp:52.586 | Rsquare:303.453
#
#
# WPEM 9-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.578
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5471226964493932
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.002, [2, 1, 1.5]], ['CuII', '2p1/2', 953.397, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.952], ['CuII', '2p3/2', 943.081], ['CuII', '2p1/2', 962.382]]]
# Rp:46.604 | Rwp:52.605 | Rsquare:303.732
#
#
# WPEM 10-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.578
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5466410393260575
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.004, [2, 1, 1.5]], ['CuII', '2p1/2', 953.399, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.948], ['CuII', '2p3/2', 943.079], ['CuII', '2p1/2', 962.382]]]
#  65%|███████████████████████████▉               | 13/20 [00:00<00:00, 38.30it/s]
# Rp:46.624 | Rwp:52.624 | Rsquare:304.002
#
#
# WPEM 11-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.578
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5462793339124323
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.005, [2, 1, 1.5]], ['CuII', '2p1/2', 953.4, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.944], ['CuII', '2p3/2', 943.076], ['CuII', '2p1/2', 962.381]]]
# Rp:46.642 | Rwp:52.641 | Rsquare:304.250
#
#
# WPEM 12-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.578
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5460130342684456
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.007, [2, 1, 1.5]], ['CuII', '2p1/2', 953.401, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.941], ['CuII', '2p3/2', 943.073], ['CuII', '2p1/2', 962.381]]]
# Rp:46.659 | Rwp:52.657 | Rsquare:304.475
#
#
# WPEM 13-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5458255139673034
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.01, [2, 1, 1.5]], ['CuII', '2p1/2', 953.401, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.938], ['CuII', '2p3/2', 943.071], ['CuII', '2p1/2', 962.38]]]
# Rp:46.674 | Rwp:52.670 | Rsquare:304.665
#
#
# WPEM 14-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5457048374868475
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.011, [2, 1, 1.5]], ['CuII', '2p1/2', 953.403, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.935], ['CuII', '2p3/2', 943.069], ['CuII', '2p1/2', 962.379]]]
# Rp:46.689 | Rwp:52.683 | Rsquare:304.851
#
#
# WPEM 15-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5456409323124414
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.013, [2, 1, 1.5]], ['CuII', '2p1/2', 953.404, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.933], ['CuII', '2p3/2', 943.067], ['CuII', '2p1/2', 962.378]]]
# Rp:46.703 | Rwp:52.694 | Rsquare:305.020
#
#
# WPEM 16-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5456258295864774
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.014, [2, 1, 1.5]], ['CuII', '2p1/2', 953.406, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.93], ['CuII', '2p3/2', 943.065], ['CuII', '2p1/2', 962.377]]]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 38.12it/s]
# Rp:46.716 | Rwp:52.704 | Rsquare:305.172
#
#
# WPEM 17-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5456527479592076
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.016, [2, 1, 1.5]], ['CuII', '2p1/2', 953.407, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.928], ['CuII', '2p3/2', 943.064], ['CuII', '2p1/2', 962.376]]]
# Rp:46.729 | Rwp:52.714 | Rsquare:305.311
#
#
# WPEM 18-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.577
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5457158343088402
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.017, [2, 1, 1.5]], ['CuII', '2p1/2', 953.409, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.926], ['CuII', '2p3/2', 943.062], ['CuII', '2p1/2', 962.374]]]
# Rp:46.740 | Rwp:52.722 | Rsquare:305.438
#
#
# WPEM 19-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.576
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5458100048974925
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.02, [2, 1, 1.5]], ['CuII', '2p1/2', 953.409, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 940.924], ['CuII', '2p3/2', 943.061], ['CuII', '2p1/2', 962.373]]]
# Rp:46.749 | Rwp:52.728 | Rsquare:305.539
#
#
# After update the background :   Rp = 46.749 | Rwp = 52.728 | Rsquare = 305.539
# 20-th iterations, reach the maximum number of iteration steps.
#  Rp: 46.749
# Rwp: 52.728
#
#
# WPEM-XPS program running time :  0 hours 0 minute  4 second
# '0 hours 0 minute  4 second  '
