# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-03-05 10:31:37  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,segement=[[910,931],[948,952],[958,959],[966,970]],bac_num=120,Model='XPS',noise = 0.05,bac_var_type='multivariate gaussian')

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM

var = 0.1
AtomIdentifier = [['CuII','2p3/2',933.7,],['CuII','2p1/2',954,],]
satellitePeaks = [['CuII', '2p3/2',941.6,],['CuII','2p3/2',943.4],['CuII','2p1/2',962.5,],]
# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
var, AtomIdentifier, satellitePeaks,no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.80,iter_max = 500, InitializationEpoch=1,)
# Out:
# Started at Tue Mar  5 11:16:28 2024
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#   1%|▎                                          | 3/500 [00:00<00:17, 28.06it/s]
# WPEM 0-th iteration
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.7, [2, 1, 1.5]], ['CuII', '2p1/2', 954, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.6], ['CuII', '2p3/2', 943.4], ['CuII', '2p1/2', 962.5]]]
# Rp:45.523 | Rwp:51.131 | Rsquare:287.228
#
#
# WPEM 1-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.802
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5618759319584328
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.879, [2, 1, 1.5]], ['CuII', '2p1/2', 953.962, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.453], ['CuII', '2p3/2', 943.325], ['CuII', '2p1/2', 962.382]]]
# Rp:46.157 | Rwp:52.339 | Rsquare:299.751
#
#
# WPEM 2-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.798
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.55002114019764
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.884, [2, 1, 1.5]], ['CuII', '2p1/2', 953.954, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.489], ['CuII', '2p3/2', 943.371], ['CuII', '2p1/2', 962.385]]]
# Rp:46.271 | Rwp:52.505 | Rsquare:301.385
#
#
# WPEM 3-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.795
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5473808825755723
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.89, [2, 1, 1.5]], ['CuII', '2p1/2', 953.951, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.49], ['CuII', '2p3/2', 943.404], ['CuII', '2p1/2', 962.385]]]
# Rp:46.345 | Rwp:52.587 | Rsquare:302.303
#
#
# WPEM 4-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.793
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5461102523107344
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.895, [2, 1, 1.5]], ['CuII', '2p1/2', 953.95, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.489], ['CuII', '2p3/2', 943.428], ['CuII', '2p1/2', 962.383]]]
# Rp:46.405 | Rwp:52.644 | Rsquare:302.981
#
#
# WPEM 5-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.792
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5452794616737118
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.898, [2, 1, 1.5]], ['CuII', '2p1/2', 953.95, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.488], ['CuII', '2p3/2', 943.445], ['CuII', '2p1/2', 962.38]]]
# Rp:46.456 | Rwp:52.692 | Rsquare:303.562
#
#
# WPEM 6-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.791
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5447783510107471
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.902, [2, 1, 1.5]], ['CuII', '2p1/2', 953.951, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.485], ['CuII', '2p3/2', 943.457], ['CuII', '2p1/2', 962.378]]]
#   1%|▌                                          | 7/500 [00:00<00:14, 34.86it/s]
# Rp:46.501 | Rwp:52.734 | Rsquare:304.071
#
#
# WPEM 7-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.789
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5445777626597298
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.907, [2, 1, 1.5]], ['CuII', '2p1/2', 953.95, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.482], ['CuII', '2p3/2', 943.465], ['CuII', '2p1/2', 962.375]]]
# Rp:46.539 | Rwp:52.771 | Rsquare:304.515
#
#
# WPEM 8-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.789
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5446442913277754
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.909, [2, 1, 1.5]], ['CuII', '2p1/2', 953.952, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.479], ['CuII', '2p3/2', 943.471], ['CuII', '2p1/2', 962.372]]]
# Rp:46.576 | Rwp:52.806 | Rsquare:304.945
#
#
# WPEM 9-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.788
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5449405034039789
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.912, [2, 1, 1.5]], ['CuII', '2p1/2', 953.952, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.477], ['CuII', '2p3/2', 943.475], ['CuII', '2p1/2', 962.369]]]
#   2%|▉                                         | 11/500 [00:00<00:13, 35.70it/s]
# Rp:46.608 | Rwp:52.838 | Rsquare:305.328
#
#
# WPEM 10-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.787
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5454290807685939
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.916, [2, 1, 1.5]], ['CuII', '2p1/2', 953.952, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.474], ['CuII', '2p3/2', 943.478], ['CuII', '2p1/2', 962.366]]]
# Rp:46.637 | Rwp:52.867 | Rsquare:305.684
#
#
# WPEM 11-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.786
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5460763258198222
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.919, [2, 1, 1.5]], ['CuII', '2p1/2', 953.953, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.471], ['CuII', '2p3/2', 943.481], ['CuII', '2p1/2', 962.364]]]
# Rp:46.664 | Rwp:52.895 | Rsquare:306.017
#
#
# WPEM 12-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.786
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5468529127037438
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.921, [2, 1, 1.5]], ['CuII', '2p1/2', 953.955, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.469], ['CuII', '2p3/2', 943.482], ['CuII', '2p1/2', 962.361]]]
# Rp:46.690 | Rwp:52.922 | Rsquare:306.343
#
#
# WPEM 13-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.785
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.547734029785221
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.925, [2, 1, 1.5]], ['CuII', '2p1/2', 953.955, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.466], ['CuII', '2p3/2', 943.484], ['CuII', '2p1/2', 962.358]]]
# Rp:46.714 | Rwp:52.947 | Rsquare:306.637
#
#
# WPEM 14-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.784
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5486982671045428
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.928, [2, 1, 1.5]], ['CuII', '2p1/2', 953.955, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.464], ['CuII', '2p3/2', 943.485], ['CuII', '2p1/2', 962.355]]]
#   3%|█▎                                        | 15/500 [00:00<00:13, 36.50it/s]
# Rp:46.737 | Rwp:52.970 | Rsquare:306.914
#
#
# WPEM 15-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.784
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5497278170819859
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.93, [2, 1, 1.5]], ['CuII', '2p1/2', 953.957, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.463], ['CuII', '2p3/2', 943.485], ['CuII', '2p1/2', 962.352]]]
# Rp:46.760 | Rwp:52.992 | Rsquare:307.189
#
#
# WPEM 16-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.783
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5508081080450674
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.934, [2, 1, 1.5]], ['CuII', '2p1/2', 953.958, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.461], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.349]]]
# Rp:46.781 | Rwp:53.013 | Rsquare:307.436
#
#
# WPEM 17-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.783
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5519264083909552
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.935, [2, 1, 1.5]], ['CuII', '2p1/2', 953.959, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.459], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.346]]]
# Rp:46.802 | Rwp:53.033 | Rsquare:307.684
#
#
# WPEM 18-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.782
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5530726649574953
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.939, [2, 1, 1.5]], ['CuII', '2p1/2', 953.96, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.458], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.344]]]
# Rp:46.820 | Rwp:53.051 | Rsquare:307.904
#   4%|█▌                                        | 19/500 [00:00<00:12, 37.57it/s]
# WPEM 19-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.782
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5542379661547302
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.941, [2, 1, 1.5]], ['CuII', '2p1/2', 953.962, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.457], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.341]]]
# Rp:46.839 | Rwp:53.069 | Rsquare:308.126
#
#
# WPEM 20-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.782
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.555415514824787
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.942, [2, 1, 1.5]], ['CuII', '2p1/2', 953.963, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.456], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.338]]]
# Rp:46.857 | Rwp:53.086 | Rsquare:308.336
#
#
# WPEM 21-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.781
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5565993494793671
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.946, [2, 1, 1.5]], ['CuII', '2p1/2', 953.963, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.455], ['CuII', '2p3/2', 943.486], ['CuII', '2p1/2', 962.336]]]
# Rp:46.873 | Rwp:53.101 | Rsquare:308.520
#
#
# WPEM 22-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.781
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5577842723196595
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.947, [2, 1, 1.5]], ['CuII', '2p1/2', 953.965, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.454], ['CuII', '2p3/2', 943.485], ['CuII', '2p1/2', 962.333]]]
# Rp:46.889 | Rwp:53.116 | Rsquare:308.708
#   5%|██▎                                       | 27/500 [00:00<00:12, 38.75it/s]
# WPEM 23-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.78
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5589666015842073
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.951, [2, 1, 1.5]], ['CuII', '2p1/2', 953.965, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.453], ['CuII', '2p3/2', 943.485], ['CuII', '2p1/2', 962.331]]]
# Rp:46.903 | Rwp:53.128 | Rsquare:308.871
#
#
# WPEM 24-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.78
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5601426874962596
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.952, [2, 1, 1.5]], ['CuII', '2p1/2', 953.967, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.452], ['CuII', '2p3/2', 943.484], ['CuII', '2p1/2', 962.329]]]
# Rp:46.917 | Rwp:53.142 | Rsquare:309.039
#
#
# WPEM 25-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.78
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5613101810726124
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.954, [2, 1, 1.5]], ['CuII', '2p1/2', 953.969, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.451], ['CuII', '2p3/2', 943.484], ['CuII', '2p1/2', 962.326]]]
# Rp:46.931 | Rwp:53.154 | Rsquare:309.198
#
#
# WPEM 26-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.78
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.562466771875053
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.956, [2, 1, 1.5]], ['CuII', '2p1/2', 953.97, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.451], ['CuII', '2p3/2', 943.483], ['CuII', '2p1/2', 962.324]]]
# Rp:46.944 | Rwp:53.166 | Rsquare:309.348
#
#
# WPEM 27-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.779
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5636105401761464
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.959, [2, 1, 1.5]], ['CuII', '2p1/2', 953.97, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.45], ['CuII', '2p3/2', 943.483], ['CuII', '2p1/2', 962.322]]]
# Rp:46.956 | Rwp:53.175 | Rsquare:309.475
#
#
# WPEM 28-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.779
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5647396669176261
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.96, [2, 1, 1.5]], ['CuII', '2p1/2', 953.972, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.45], ['CuII', '2p3/2', 943.482], ['CuII', '2p1/2', 962.32]]]
# Rp:46.967 | Rwp:53.186 | Rsquare:309.609
#
#
# WPEM 29-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.779
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5658533204066241
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.962, [2, 1, 1.5]], ['CuII', '2p1/2', 953.973, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.449], ['CuII', '2p3/2', 943.481], ['CuII', '2p1/2', 962.318]]]
# Rp:46.979 | Rwp:53.195 | Rsquare:309.736
#
#
# WPEM 30-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.778
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5669504707704249
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.965, [2, 1, 1.5]], ['CuII', '2p1/2', 953.973, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.449], ['CuII', '2p3/2', 943.48], ['CuII', '2p1/2', 962.317]]]
# Rp:46.988 | Rwp:53.203 | Rsquare:309.841
#
#
# WPEM 31-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.778
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5680299590671216
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.966, [2, 1, 1.5]], ['CuII', '2p1/2', 953.975, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.448], ['CuII', '2p3/2', 943.479], ['CuII', '2p1/2', 962.315]]]
# Rp:46.998 | Rwp:53.211 | Rsquare:309.955
#   7%|███                                       | 36/500 [00:00<00:11, 39.56it/s]
# WPEM 32-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.778
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5690915709586418
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.967, [2, 1, 1.5]], ['CuII', '2p1/2', 953.976, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.448], ['CuII', '2p3/2', 943.479], ['CuII', '2p1/2', 962.313]]]
# Rp:47.008 | Rwp:53.219 | Rsquare:310.062
#
#
# WPEM 33-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.778
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.570134762686106
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.969, [2, 1, 1.5]], ['CuII', '2p1/2', 953.977, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.447], ['CuII', '2p3/2', 943.478], ['CuII', '2p1/2', 962.312]]]
# Rp:47.017 | Rwp:53.227 | Rsquare:310.164
#
#
# WPEM 34-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.777
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5711590890852973
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.972, [2, 1, 1.5]], ['CuII', '2p1/2', 953.977, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.447], ['CuII', '2p3/2', 943.477], ['CuII', '2p1/2', 962.31]]]
# Rp:47.024 | Rwp:53.232 | Rsquare:310.245
#
#
# WPEM 35-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.777
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.572163929682376
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.973, [2, 1, 1.5]], ['CuII', '2p1/2', 953.978, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.447], ['CuII', '2p3/2', 943.476], ['CuII', '2p1/2', 962.309]]]
# Rp:47.032 | Rwp:53.239 | Rsquare:310.336
#
#
# WPEM 36-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.777
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5731495352436993
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.974, [2, 1, 1.5]], ['CuII', '2p1/2', 953.979, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.446], ['CuII', '2p3/2', 943.475], ['CuII', '2p1/2', 962.307]]]
# Rp:47.040 | Rwp:53.245 | Rsquare:310.423
#
#
# WPEM 37-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.777
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5741157457574222
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.975, [2, 1, 1.5]], ['CuII', '2p1/2', 953.981, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.446], ['CuII', '2p3/2', 943.474], ['CuII', '2p1/2', 962.306]]]
# Rp:47.048 | Rwp:53.251 | Rsquare:310.505
#
#
# WPEM 38-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.776
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5750624428010566
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.978, [2, 1, 1.5]], ['CuII', '2p1/2', 953.98, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.446], ['CuII', '2p3/2', 943.473], ['CuII', '2p1/2', 962.305]]]
#   8%|███▍                                      | 41/500 [00:01<00:11, 39.69it/s]
# Rp:47.053 | Rwp:53.255 | Rsquare:310.567
#
#
# WPEM 39-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.776
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.575989266637905
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.979, [2, 1, 1.5]], ['CuII', '2p1/2', 953.981, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.446], ['CuII', '2p3/2', 943.473], ['CuII', '2p1/2', 962.304]]]
# Rp:47.061 | Rwp:53.261 | Rsquare:310.641
#
#
# WPEM 40-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.776
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5768967314796591
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.98, [2, 1, 1.5]], ['CuII', '2p1/2', 953.982, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.446], ['CuII', '2p3/2', 943.472], ['CuII', '2p1/2', 962.303]]]
# Rp:47.068 | Rwp:53.265 | Rsquare:310.711
#
#
# WPEM 41-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.776
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5777848817064974
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.981, [2, 1, 1.5]], ['CuII', '2p1/2', 953.983, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.471], ['CuII', '2p1/2', 962.302]]]
# Rp:47.075 | Rwp:53.270 | Rsquare:310.777
#
#
# WPEM 42-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.775
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5786537766836743
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.983, [2, 1, 1.5]], ['CuII', '2p1/2', 953.983, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.47], ['CuII', '2p1/2', 962.301]]]
# Rp:47.080 | Rwp:53.273 | Rsquare:310.825
#
#
# WPEM 43-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.775
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5795031828799188
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.984, [2, 1, 1.5]], ['CuII', '2p1/2', 953.984, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.469], ['CuII', '2p1/2', 962.3]]]
#   9%|███▊                                      | 45/500 [00:01<00:11, 39.44it/s]
# Rp:47.087 | Rwp:53.277 | Rsquare:310.885
#
#
# WPEM 44-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.775
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5803337871417336
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.985, [2, 1, 1.5]], ['CuII', '2p1/2', 953.985, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.469], ['CuII', '2p1/2', 962.299]]]
# Rp:47.093 | Rwp:53.281 | Rsquare:310.941
#
#
# WPEM 45-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.775
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5811457455750184
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.986, [2, 1, 1.5]], ['CuII', '2p1/2', 953.985, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.468], ['CuII', '2p1/2', 962.298]]]
# Rp:47.099 | Rwp:53.285 | Rsquare:310.995
#
#
# WPEM 46-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.774
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5819392152741891
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.989, [2, 1, 1.5]], ['CuII', '2p1/2', 953.985, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.467], ['CuII', '2p1/2', 962.298]]]
# Rp:47.103 | Rwp:53.287 | Rsquare:311.031
#
#
# WPEM 47-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.774
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5827140106982933
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.989, [2, 1, 1.5]], ['CuII', '2p1/2', 953.986, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.466], ['CuII', '2p1/2', 962.297]]]
# Rp:47.108 | Rwp:53.290 | Rsquare:311.080
#
#
# WPEM 48-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.774
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5834709451114524
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.99, [2, 1, 1.5]], ['CuII', '2p1/2', 953.986, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.466], ['CuII', '2p1/2', 962.296]]]
# Rp:47.113 | Rwp:53.293 | Rsquare:311.126
#  10%|████                                      | 49/500 [00:01<00:11, 39.38it/s]
# WPEM 49-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.774
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5842102312088732
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.991, [2, 1, 1.5]], ['CuII', '2p1/2', 953.987, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.465], ['CuII', '2p1/2', 962.296]]]
# Rp:47.118 | Rwp:53.296 | Rsquare:311.171
#
#
# WPEM 50-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.774
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5849320755584246
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.992, [2, 1, 1.5]], ['CuII', '2p1/2', 953.988, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.464], ['CuII', '2p1/2', 962.295]]]
# Rp:47.123 | Rwp:53.299 | Rsquare:311.213
#
#
# WPEM 51-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.773
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5856367291849796
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.994, [2, 1, 1.5]], ['CuII', '2p1/2', 953.987, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.463], ['CuII', '2p1/2', 962.294]]]
# Rp:47.126 | Rwp:53.300 | Rsquare:311.237
#
#
# WPEM 52-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.773
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5863240492149562
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.995, [2, 1, 1.5]], ['CuII', '2p1/2', 953.988, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.463], ['CuII', '2p1/2', 962.294]]]
# Rp:47.131 | Rwp:53.303 | Rsquare:311.275
#  11%|████▊                                     | 57/500 [00:01<00:11, 39.21it/s]
# WPEM 53-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.773
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5869949344326895
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.995, [2, 1, 1.5]], ['CuII', '2p1/2', 953.988, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.462], ['CuII', '2p1/2', 962.293]]]
# Rp:47.135 | Rwp:53.305 | Rsquare:311.311
#
#
# WPEM 54-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.773
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5876496326335409
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.996, [2, 1, 1.5]], ['CuII', '2p1/2', 953.989, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.462], ['CuII', '2p1/2', 962.293]]]
# Rp:47.139 | Rwp:53.307 | Rsquare:311.346
#
#
# WPEM 55-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.773
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5882883772284606
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.997, [2, 1, 1.5]], ['CuII', '2p1/2', 953.99, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.461], ['CuII', '2p1/2', 962.293]]]
# Rp:47.142 | Rwp:53.310 | Rsquare:311.379
#
#
# WPEM 56-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.772
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5889114404528629
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.999, [2, 1, 1.5]], ['CuII', '2p1/2', 953.989, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.46], ['CuII', '2p1/2', 962.292]]]
# Rp:47.145 | Rwp:53.310 | Rsquare:311.394
#
#
# WPEM 57-th iteration
#  12%|█████                                     | 61/500 [00:01<00:11, 39.40it/s]
# Under the central field approximation, the effective charge of CuII is: 25.772
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5895186563846059
# The energies of electrons are:
# [[['CuII', '2p3/2', 933.999, [2, 1, 1.5]], ['CuII', '2p1/2', 953.989, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.46], ['CuII', '2p1/2', 962.292]]]
# Rp:47.148 | Rwp:53.312 | Rsquare:311.424
#
#
# WPEM 58-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.772
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5901109867152098
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.0, [2, 1, 1.5]], ['CuII', '2p1/2', 953.99, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.459], ['CuII', '2p1/2', 962.292]]]
# Rp:47.151 | Rwp:53.314 | Rsquare:311.452
#
#
# WPEM 59-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.772
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.590688678387596
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.0, [2, 1, 1.5]], ['CuII', '2p1/2', 953.99, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.459], ['CuII', '2p1/2', 962.291]]]
# Rp:47.154 | Rwp:53.316 | Rsquare:311.479
#
#
# WPEM 60-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.772
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5912519619146128
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.001, [2, 1, 1.5]], ['CuII', '2p1/2', 953.991, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.458], ['CuII', '2p1/2', 962.291]]]
# Rp:47.157 | Rwp:53.317 | Rsquare:311.505
#  13%|█████▍                                    | 65/500 [00:01<00:10, 39.57it/s]
# WPEM 61-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5918011058637087
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.003, [2, 1, 1.5]], ['CuII', '2p1/2', 953.99, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.458], ['CuII', '2p1/2', 962.291]]]
# Rp:47.159 | Rwp:53.317 | Rsquare:311.513
#
#
# WPEM 62-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5923358891191841
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.004, [2, 1, 1.5]], ['CuII', '2p1/2', 953.99, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.457], ['CuII', '2p1/2', 962.29]]]
# Rp:47.162 | Rwp:53.319 | Rsquare:311.537
#
#
# WPEM 63-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5928573347423569
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.004, [2, 1, 1.5]], ['CuII', '2p1/2', 953.991, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.457], ['CuII', '2p1/2', 962.29]]]
# Rp:47.164 | Rwp:53.320 | Rsquare:311.559
#
#
# WPEM 64-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5933656693633812
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.004, [2, 1, 1.5]], ['CuII', '2p1/2', 953.991, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.456], ['CuII', '2p1/2', 962.29]]]
# Rp:47.167 | Rwp:53.322 | Rsquare:311.581
#
#
# WPEM 65-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5938611046308024
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.005, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.456], ['CuII', '2p1/2', 962.29]]]
# Rp:47.169 | Rwp:53.323 | Rsquare:311.601
#
#
# WPEM 66-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.771
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5943438922533735
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.005, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.456], ['CuII', '2p1/2', 962.29]]]
# Rp:47.171 | Rwp:53.324 | Rsquare:311.620
#
#
# WPEM 67-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5948143014101709
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.007, [2, 1, 1.5]], ['CuII', '2p1/2', 953.991, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.455], ['CuII', '2p1/2', 962.29]]]
# Rp:47.172 | Rwp:53.324 | Rsquare:311.623
#
#
# WPEM 68-th iteration
#  14%|█████▉                                    | 70/500 [00:01<00:10, 39.77it/s]
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5952720539965055
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.008, [2, 1, 1.5]], ['CuII', '2p1/2', 953.991, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.455], ['CuII', '2p1/2', 962.289]]]
# Rp:47.174 | Rwp:53.325 | Rsquare:311.640
#
#
# WPEM 69-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5957182183020476
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.008, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.455], ['CuII', '2p1/2', 962.289]]]
# Rp:47.176 | Rwp:53.326 | Rsquare:311.657
#  15%|██████▏                                   | 74/500 [00:01<00:10, 39.65it/s]
# WPEM 70-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.596152991698368
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.008, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.454], ['CuII', '2p1/2', 962.289]]]
# Rp:47.178 | Rwp:53.327 | Rsquare:311.673
#
#
# WPEM 71-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.596576557246698
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.009, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.454], ['CuII', '2p1/2', 962.289]]]
# Rp:47.180 | Rwp:53.328 | Rsquare:311.688
#
#
# WPEM 72-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5969891401749925
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.009, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.453], ['CuII', '2p1/2', 962.289]]]
# Rp:47.182 | Rwp:53.329 | Rsquare:311.703
#
#
# WPEM 73-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.77
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5973909833145004
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.009, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.453], ['CuII', '2p1/2', 962.289]]]
# Rp:47.184 | Rwp:53.329 | Rsquare:311.717
#
#
# WPEM 74-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5977823344763539
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.011, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.453], ['CuII', '2p1/2', 962.289]]]
# Rp:47.184 | Rwp:53.329 | Rsquare:311.714
#
#
# WPEM 75-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5981628432604588
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.012, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.453], ['CuII', '2p1/2', 962.289]]]
# Rp:47.185 | Rwp:53.329 | Rsquare:311.727
#
#
# WPEM 76-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5985336115206121
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.012, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.452], ['CuII', '2p1/2', 962.289]]]
# Rp:47.187 | Rwp:53.330 | Rsquare:311.739
#
#
# WPEM 77-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.598894797709739
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.012, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.452], ['CuII', '2p1/2', 962.289]]]
# Rp:47.188 | Rwp:53.331 | Rsquare:311.751
#  16%|██████▌                                   | 78/500 [00:02<00:10, 39.75it/s]
# WPEM 78-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.5992465476472679
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.012, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.452], ['CuII', '2p1/2', 962.289]]]
# Rp:47.190 | Rwp:53.332 | Rsquare:311.762
#
#
# WPEM 79-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.599589052405181
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.013, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.451], ['CuII', '2p1/2', 962.289]]]
# Rp:47.191 | Rwp:53.332 | Rsquare:311.772
#
#
# WPEM 80-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.599922521567371
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.013, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.451], ['CuII', '2p1/2', 962.289]]]
#  17%|██████▉                                   | 83/500 [00:02<00:10, 39.91it/s]
# Rp:47.192 | Rwp:53.333 | Rsquare:311.782
#
#
# WPEM 81-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.769
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6002471699616876
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.013, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.451], ['CuII', '2p1/2', 962.289]]]
# Rp:47.194 | Rwp:53.333 | Rsquare:311.792
#
#
# WPEM 82-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6005632123442661
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.015, [2, 1, 1.5]], ['CuII', '2p1/2', 953.992, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.451], ['CuII', '2p1/2', 962.289]]]
# Rp:47.193 | Rwp:53.332 | Rsquare:311.785
#
#
# WPEM 83-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6008702137137707
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.015, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.45], ['CuII', '2p1/2', 962.289]]]
# Rp:47.194 | Rwp:53.333 | Rsquare:311.794
#
#
# WPEM 84-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6011693093753085
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.015, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.45], ['CuII', '2p1/2', 962.289]]]
# Rp:47.196 | Rwp:53.333 | Rsquare:311.802
#
#
# WPEM 85-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6014606123147584
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.016, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.45], ['CuII', '2p1/2', 962.289]]]
# Rp:47.197 | Rwp:53.334 | Rsquare:311.810
#
#
# WPEM 86-th iteration
#  17%|███████▎                                  | 87/500 [00:02<00:10, 39.73it/s]
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6017442258595409
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.016, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.45], ['CuII', '2p1/2', 962.289]]]
# Rp:47.198 | Rwp:53.334 | Rsquare:311.818
#
#
# WPEM 87-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6020203026462199
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.016, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.45], ['CuII', '2p1/2', 962.289]]]
# Rp:47.199 | Rwp:53.335 | Rsquare:311.825
#
#
# WPEM 88-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6022890153731546
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.016, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.199 | Rwp:53.335 | Rsquare:311.833
#
#
# WPEM 89-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
#  18%|███████▋                                  | 91/500 [00:02<00:10, 39.13it/s]
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6025505427234936
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.017, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.200 | Rwp:53.335 | Rsquare:311.839
#
#
# WPEM 90-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.768
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6028050638300919
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.017, [2, 1, 1.5]], ['CuII', '2p1/2', 953.994, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.201 | Rwp:53.336 | Rsquare:311.846
#
#
# WPEM 91-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.767
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6030527559679784
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.018, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.201 | Rwp:53.334 | Rsquare:311.835
#
#
# WPEM 92-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.767
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6032930893505719
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.019, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.201 | Rwp:53.335 | Rsquare:311.841
#
#
# WPEM 93-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.767
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6035272424637892
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.019, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.444], ['CuII', '2p3/2', 943.449], ['CuII', '2p1/2', 962.289]]]
# Rp:47.202 | Rwp:53.335 | Rsquare:311.847
#
#
# WPEM 94-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.767
# ...
#
#
# WPEM 469-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120481046891227
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 470-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120485710333267
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 471-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120490370671555
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 472-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.612049502795365
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
#  95%|██████████████████████████████████████▊  | 473/500 [00:12<00:00, 38.97it/s]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 473-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120499682224959
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 474-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120504333528767
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 475-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120508981906234
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.945
#
#
# WPEM 476-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.61205136273964
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#  95%|███████████████████████████████████████  | 477/500 [00:12<00:00, 39.27it/s]
# WPEM 477-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120518270036192
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 478-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120522909860404
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 479-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120527546901715
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 480-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120532181190665
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#  96%|███████████████████████████████████████▍ | 481/500 [00:12<00:00, 39.47it/s]
# WPEM 481-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120536812755654
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 482-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120541441622909
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 483-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120546067816486
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 484-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.612055069135824
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 485-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120555312267799
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
#  98%|████████████████████████████████████████▏| 490/500 [00:12<00:00, 39.95it/s]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 486-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120559930562525
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 487-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120564546257505
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 488-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120569159365494
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 489-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120573769896875
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 490-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120578377859611
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 491-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120582983259213
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 492-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.612058758609866
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 493-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120592186378357
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 494-th iteration
# Under the central field approximation, the effective charge of CuII is:
# 100%|█████████████████████████████████████████| 500/500 [00:12<00:00, 39.34it/s]
#  25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120596784096051
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 495-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120601379246784
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 496-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120605971822797
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 497-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120610561813449
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.946
#
#
# WPEM 498-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120615149205137
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.947
#
#
# WPEM 499-th iteration
# Under the central field approximation, the effective charge of CuII is: 25.763
# The Integrated Energy ratio for satellite peak of [('CuII', '2p3/2'), ('CuII', '2p1/2')] is 0.6120619733981196
# The energies of electrons are:
# [[['CuII', '2p3/2', 934.031, [2, 1, 1.5]], ['CuII', '2p1/2', 953.993, [2, 1, 0.5]]]]
# The energies of satellite peak are:
# [[['CuII', '2p3/2', 941.445], ['CuII', '2p3/2', 943.444], ['CuII', '2p1/2', 962.291]]]
# Rp:47.224 | Rwp:53.336 | Rsquare:311.947
#
#
# After update the background :   Rp = 47.224 | Rwp = 53.336 | Rsquare = 311.946
# 500-th iterations, reach the maximum number of iteration steps.
#  Rp: 47.224
# Rwp: 53.336
#
#
# WPEM-XPS program running time :  0 hours 0 minute  16 second
# '0 hours 0 minute  16 second  '
