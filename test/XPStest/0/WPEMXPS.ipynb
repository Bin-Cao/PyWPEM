# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-11-08 19:26:13  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,bac_split=7,lowAngleRange=905,bac_num=180,Model='XPS',noise = 0.3,bac_var_type='multivariate gaussian')
# Out:
# /Users/jacob/Documents/GitHub/PyWPEM/Background/BacDeduct.py:293: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Intensity_mean, Intensity_dev = model.predict(angle[:, np.newaxis], return_std=True)

# %%
AtomIdentifier = [['Cu','2p3/2',932.9],['Cu','2p1/2',952.5],]

# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.90,iter_max = 100, asy_C = 0.,
    )
# Out:
# Started at Wed Nov  8 19:45:13 2023
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#
# WPEM 1-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:5.442 | Rwp:9.457 | Rsquare:9.387
#
#
# WPEM 2-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:4.629 | Rwp:7.850 | Rsquare:6.785
#
#
# Under the central field approximation, the effective charge of Cu is: 25.67
# WPEM 3-th iteration
# ['Cu', '2p3/2', 932.848]
# ['Cu', '2p1/2', 952.523]
# Rp:4.147 | Rwp:7.096 | Rsquare:5.820
#
#
# Under the central field approximation, the effective charge of Cu is: 25.68
# WPEM 4-th iteration
# ['Cu', '2p3/2', 932.831]
# ['Cu', '2p1/2', 952.537]
# Rp:3.797 | Rwp:5.997 | Rsquare:3.664
#
#
# Under the central field approximation, the effective charge of Cu is: 25.68
# WPEM 5-th iteration
# ['Cu', '2p3/2', 932.831]
# ['Cu', '2p1/2', 952.537]
# Rp:3.622 | Rwp:5.517 | Rsquare:2.880
#
#
# Under the central field approximation, the effective charge of Cu is: 25.68
# WPEM 6-th iteration
# ['Cu', '2p3/2', 932.831]
# ['Cu', '2p1/2', 952.537]
# Rp:3.493 | Rwp:5.210 | Rsquare:2.438
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 7-th iteration
# ['Cu', '2p3/2', 932.816]
# ['Cu', '2p1/2', 952.552]
# Rp:3.290 | Rwp:4.672 | Rsquare:1.741
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 8-th iteration
# ['Cu', '2p3/2', 932.816]
# ['Cu', '2p1/2', 952.553]
# Rp:3.230 | Rwp:4.554 | Rsquare:1.624
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 9-th iteration
# ['Cu', '2p3/2', 932.817]
# ['Cu', '2p1/2', 952.553]
# Rp:3.197 | Rwp:4.482 | Rsquare:1.563
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 10-th iteration
# ['Cu', '2p3/2', 932.817]
# ['Cu', '2p1/2', 952.554]
# Rp:3.171 | Rwp:4.438 | Rsquare:1.532
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 11-th iteration
# ['Cu', '2p3/2', 932.818]
# ['Cu', '2p1/2', 952.555]
# Rp:3.154 | Rwp:4.412 | Rsquare:1.518
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 12-th iteration
# ['Cu', '2p3/2', 932.818]
# ['Cu', '2p1/2', 952.555]
# Rp:3.140 | Rwp:4.395 | Rsquare:1.513
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 13-th iteration
# ['Cu', '2p3/2', 932.819]
# ['Cu', '2p1/2', 952.556]
# Rp:3.129 | Rwp:4.385 | Rsquare:1.514
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 14-th iteration
# ['Cu', '2p3/2', 932.819]
# ['Cu', '2p1/2', 952.556]
# Rp:3.120 | Rwp:4.380 | Rsquare:1.517
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 15-th iteration
# ['Cu', '2p3/2', 932.82]
# ['Cu', '2p1/2', 952.556]
# Rp:3.113 | Rwp:4.377 | Rsquare:1.521
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 16-th iteration
# ['Cu', '2p3/2', 932.82]
# ['Cu', '2p1/2', 952.557]
# Rp:3.108 | Rwp:4.376 | Rsquare:1.526
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 17-th iteration
# ['Cu', '2p3/2', 932.82]
# ['Cu', '2p1/2', 952.557]
# Rp:3.105 | Rwp:4.376 | Rsquare:1.531
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 18-th iteration
# ['Cu', '2p3/2', 932.821]
# ['Cu', '2p1/2', 952.557]
# Rp:3.101 | Rwp:4.376 | Rsquare:1.536
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 19-th iteration
# ['Cu', '2p3/2', 932.821]
# ['Cu', '2p1/2', 952.558]
# Rp:3.099 | Rwp:4.377 | Rsquare:1.541
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 20-th iteration
# ['Cu', '2p3/2', 932.821]
# ['Cu', '2p1/2', 952.558]
# Rp:3.097 | Rwp:4.379 | Rsquare:1.546
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 21-th iteration
# ['Cu', '2p3/2', 932.821]
# ['Cu', '2p1/2', 952.558]
# Rp:3.096 | Rwp:4.380 | Rsquare:1.550
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 22-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.558]
# Rp:3.095 | Rwp:4.382 | Rsquare:1.554
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 23-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.094 | Rwp:4.383 | Rsquare:1.558
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 24-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.093 | Rwp:4.385 | Rsquare:1.562
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 25-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.092 | Rwp:4.386 | Rsquare:1.565
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 26-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.092 | Rwp:4.388 | Rsquare:1.568
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 27-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.389 | Rsquare:1.570
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 28-th iteration
# ['Cu', '2p3/2', 932.822]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.390 | Rsquare:1.573
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 29-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.391 | Rsquare:1.575
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 30-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.392 | Rsquare:1.577
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 31-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.393 | Rsquare:1.579
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 32-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.559]
# Rp:3.091 | Rwp:4.394 | Rsquare:1.580
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 33-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.091 | Rwp:4.395 | Rsquare:1.582
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 34-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.091 | Rwp:4.396 | Rsquare:1.583
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 35-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.091 | Rwp:4.397 | Rsquare:1.584
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 36-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.092 | Rwp:4.397 | Rsquare:1.585
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 37-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.092 | Rwp:4.398 | Rsquare:1.586
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 38-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.092 | Rwp:4.399 | Rsquare:1.587
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 39-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.092 | Rwp:4.399 | Rsquare:1.588
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 40-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.093 | Rwp:4.400 | Rsquare:1.589
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 41-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.093 | Rwp:4.400 | Rsquare:1.590
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 42-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.093 | Rwp:4.401 | Rsquare:1.590
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 43-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.094 | Rwp:4.401 | Rsquare:1.591
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 44-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.094 | Rwp:4.402 | Rsquare:1.591
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 45-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.094 | Rwp:4.402 | Rsquare:1.592
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 46-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.095 | Rwp:4.402 | Rsquare:1.592
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 47-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.095 | Rwp:4.403 | Rsquare:1.593
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 48-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.095 | Rwp:4.403 | Rsquare:1.593
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 49-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.096 | Rwp:4.403 | Rsquare:1.594
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 50-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.096 | Rwp:4.404 | Rsquare:1.594
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 51-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.097 | Rwp:4.404 | Rsquare:1.595
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 52-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.097 | Rwp:4.404 | Rsquare:1.595
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 53-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.098 | Rwp:4.405 | Rsquare:1.596
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 54-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.098 | Rwp:4.405 | Rsquare:1.596
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 55-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.099 | Rwp:4.405 | Rsquare:1.596
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 56-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.099 | Rwp:4.406 | Rsquare:1.597
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 57-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.100 | Rwp:4.406 | Rsquare:1.597
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 58-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.100 | Rwp:4.406 | Rsquare:1.597
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 59-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.101 | Rwp:4.407 | Rsquare:1.598
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 60-th iteration
# ['Cu', '2p3/2', 932.823]
# ['Cu', '2p1/2', 952.56]
# Rp:3.101 | Rwp:4.407 | Rsquare:1.598
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 61-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.102 | Rwp:4.407 | Rsquare:1.598
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 62-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.102 | Rwp:4.408 | Rsquare:1.599
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 63-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.103 | Rwp:4.408 | Rsquare:1.599
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 64-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.104 | Rwp:4.409 | Rsquare:1.600
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 65-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.104 | Rwp:4.409 | Rsquare:1.600
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 66-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.105 | Rwp:4.409 | Rsquare:1.600
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 67-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.105 | Rwp:4.410 | Rsquare:1.601
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 68-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.106 | Rwp:4.410 | Rsquare:1.601
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 69-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.107 | Rwp:4.410 | Rsquare:1.602
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 70-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.107 | Rwp:4.411 | Rsquare:1.602
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 71-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.108 | Rwp:4.411 | Rsquare:1.602
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 72-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.108 | Rwp:4.412 | Rsquare:1.603
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 73-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.109 | Rwp:4.412 | Rsquare:1.603
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 74-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.110 | Rwp:4.413 | Rsquare:1.604
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 75-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.110 | Rwp:4.413 | Rsquare:1.604
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 76-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.111 | Rwp:4.414 | Rsquare:1.605
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 77-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.112 | Rwp:4.414 | Rsquare:1.605
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 78-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.112 | Rwp:4.415 | Rsquare:1.606
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 79-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.113 | Rwp:4.415 | Rsquare:1.606
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 80-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.56]
# Rp:3.114 | Rwp:4.416 | Rsquare:1.607
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 81-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.114 | Rwp:4.416 | Rsquare:1.607
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 82-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.115 | Rwp:4.417 | Rsquare:1.608
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 83-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.116 | Rwp:4.417 | Rsquare:1.608
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 84-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.116 | Rwp:4.418 | Rsquare:1.609
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 85-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.117 | Rwp:4.418 | Rsquare:1.610
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 86-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.118 | Rwp:4.419 | Rsquare:1.610
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 87-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.118 | Rwp:4.420 | Rsquare:1.611
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 88-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.119 | Rwp:4.420 | Rsquare:1.612
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 89-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.120 | Rwp:4.421 | Rsquare:1.612
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 90-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.121 | Rwp:4.422 | Rsquare:1.613
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 91-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.121 | Rwp:4.422 | Rsquare:1.614
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 92-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.122 | Rwp:4.423 | Rsquare:1.614
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 93-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.123 | Rwp:4.424 | Rsquare:1.615
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 94-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.124 | Rwp:4.424 | Rsquare:1.616
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 95-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.125 | Rwp:4.425 | Rsquare:1.617
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 96-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.125 | Rwp:4.426 | Rsquare:1.617
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 97-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.126 | Rwp:4.427 | Rsquare:1.618
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 98-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.127 | Rwp:4.428 | Rsquare:1.619
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 99-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.128 | Rwp:4.428 | Rsquare:1.620
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 100-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.129 | Rwp:4.429 | Rsquare:1.621
#
#
# Under the central field approximation, the effective charge of Cu is: 25.69
# WPEM 101-th iteration
# ['Cu', '2p3/2', 932.824]
# ['Cu', '2p1/2', 952.561]
# Rp:3.129 | Rwp:4.430 | Rsquare:1.622
#
#
# After update the background :   Rp = 2.033 | Rwp = 3.805 | Rsquare = 1.343
# 101-th iterations, reach the maximum number of iteration steps.
#  Rp: 2.033
# Rwp: 3.805
#
#
# WPEM-XPS program running time :  0 hours 0 minute  5 second
# '0 hours 0 minute  5 second  '
