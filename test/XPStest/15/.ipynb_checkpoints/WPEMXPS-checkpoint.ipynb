# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-11-08 19:48:12  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,bac_split=7,lowAngleRange=905,bac_num=180,Model='XPS',noise = 0.3,bac_var_type='multivariate gaussian')
# Out:
# /Users/jacob/Documents/GitHub/PyWPEM/Background/BacDeduct.py:293: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Intensity_mean, Intensity_dev = model.predict(angle[:, np.newaxis], return_std=True)

# %%
AtomIdentifier = [['Cu','2p3/2',932.9],['Cu','2p1/2',952.5],]

# The file name of non-background data 
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data 
original_file = "int.csv"  
# The file name of background data 
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.90,iter_max = 100, asy_C = 0.,
    )
# Out:
# Started at Wed Nov  8 19:48:52 2023
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#
# WPEM 1-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:8.386 | Rwp:15.806 | Rsquare:28.717
#
#
# WPEM 2-th iteration
# ['Cu', '2p3/2', 932.9]
# ['Cu', '2p1/2', 952.5]
# Rp:7.790 | Rwp:15.581 | Rsquare:26.212
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 3-th iteration
# ['Cu', '2p3/2', 932.635]
# ['Cu', '2p1/2', 952.433]
# Rp:5.013 | Rwp:9.164 | Rsquare:8.737
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 4-th iteration
# ['Cu', '2p3/2', 932.626]
# ['Cu', '2p1/2', 952.424]
# Rp:4.841 | Rwp:8.741 | Rsquare:7.917
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 5-th iteration
# ['Cu', '2p3/2', 932.618]
# ['Cu', '2p1/2', 952.416]
# Rp:4.700 | Rwp:8.428 | Rsquare:7.309
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 6-th iteration
# ['Cu', '2p3/2', 932.612]
# ['Cu', '2p1/2', 952.41]
# Rp:4.602 | Rwp:8.213 | Rsquare:6.911
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 7-th iteration
# ['Cu', '2p3/2', 932.608]
# ['Cu', '2p1/2', 952.406]
# Rp:4.533 | Rwp:8.062 | Rsquare:6.642
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 8-th iteration
# ['Cu', '2p3/2', 932.605]
# ['Cu', '2p1/2', 952.403]
# Rp:4.484 | Rwp:7.954 | Rsquare:6.455
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 9-th iteration
# ['Cu', '2p3/2', 932.603]
# ['Cu', '2p1/2', 952.401]
# Rp:4.448 | Rwp:7.876 | Rsquare:6.322
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 10-th iteration
# ['Cu', '2p3/2', 932.601]
# ['Cu', '2p1/2', 952.399]
# Rp:4.420 | Rwp:7.818 | Rsquare:6.226
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 11-th iteration
# ['Cu', '2p3/2', 932.6]
# ['Cu', '2p1/2', 952.398]
# Rp:4.399 | Rwp:7.774 | Rsquare:6.154
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 12-th iteration
# ['Cu', '2p3/2', 932.599]
# ['Cu', '2p1/2', 952.397]
# Rp:4.383 | Rwp:7.741 | Rsquare:6.101
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 13-th iteration
# ['Cu', '2p3/2', 932.598]
# ['Cu', '2p1/2', 952.396]
# Rp:4.370 | Rwp:7.715 | Rsquare:6.059
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 14-th iteration
# ['Cu', '2p3/2', 932.597]
# ['Cu', '2p1/2', 952.395]
# Rp:4.360 | Rwp:7.695 | Rsquare:6.027
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 15-th iteration
# ['Cu', '2p3/2', 932.597]
# ['Cu', '2p1/2', 952.395]
# Rp:4.352 | Rwp:7.679 | Rsquare:6.002
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 16-th iteration
# ['Cu', '2p3/2', 932.596]
# ['Cu', '2p1/2', 952.394]
# Rp:4.345 | Rwp:7.667 | Rsquare:5.982
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 17-th iteration
# ['Cu', '2p3/2', 932.596]
# ['Cu', '2p1/2', 952.394]
# Rp:4.340 | Rwp:7.656 | Rsquare:5.966
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 18-th iteration
# ['Cu', '2p3/2', 932.596]
# ['Cu', '2p1/2', 952.394]
# Rp:4.336 | Rwp:7.648 | Rsquare:5.952
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 19-th iteration
# ['Cu', '2p3/2', 932.596]
# ['Cu', '2p1/2', 952.394]
# Rp:4.332 | Rwp:7.641 | Rsquare:5.942
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 20-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.394]
# Rp:4.329 | Rwp:7.635 | Rsquare:5.933
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 21-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.326 | Rwp:7.631 | Rsquare:5.926
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 22-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.324 | Rwp:7.627 | Rsquare:5.919
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 23-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.322 | Rwp:7.624 | Rsquare:5.914
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 24-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.320 | Rwp:7.621 | Rsquare:5.910
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 25-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.319 | Rwp:7.618 | Rsquare:5.906
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 26-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.317 | Rwp:7.616 | Rsquare:5.903
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 27-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.316 | Rwp:7.615 | Rsquare:5.901
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 28-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.315 | Rwp:7.613 | Rsquare:5.898
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 29-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.314 | Rwp:7.612 | Rsquare:5.896
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 30-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.313 | Rwp:7.611 | Rsquare:5.895
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 31-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.313 | Rwp:7.610 | Rsquare:5.893
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 32-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.312 | Rwp:7.609 | Rsquare:5.892
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 33-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.311 | Rwp:7.608 | Rsquare:5.891
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 34-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.311 | Rwp:7.607 | Rsquare:5.890
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 35-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.310 | Rwp:7.607 | Rsquare:5.889
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 36-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.310 | Rwp:7.606 | Rsquare:5.888
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 37-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.309 | Rwp:7.606 | Rsquare:5.887
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 38-th iteration
# ['Cu', '2p3/2', 932.595]
# ['Cu', '2p1/2', 952.393]
# Rp:4.309 | Rwp:7.605 | Rsquare:5.887
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 39-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.309 | Rwp:7.605 | Rsquare:5.886
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 40-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.308 | Rwp:7.604 | Rsquare:5.885
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 41-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.308 | Rwp:7.604 | Rsquare:5.885
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 42-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.308 | Rwp:7.604 | Rsquare:5.884
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 43-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.307 | Rwp:7.603 | Rsquare:5.884
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 44-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.307 | Rwp:7.603 | Rsquare:5.884
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 45-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.307 | Rwp:7.603 | Rsquare:5.883
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 46-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.306 | Rwp:7.602 | Rsquare:5.883
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 47-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.306 | Rwp:7.602 | Rsquare:5.882
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 48-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.306 | Rwp:7.602 | Rsquare:5.882
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 49-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.306 | Rwp:7.601 | Rsquare:5.882
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 50-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.305 | Rwp:7.601 | Rsquare:5.881
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 51-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.305 | Rwp:7.601 | Rsquare:5.881
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 52-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.305 | Rwp:7.601 | Rsquare:5.880
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 53-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.305 | Rwp:7.600 | Rsquare:5.880
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 54-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.304 | Rwp:7.600 | Rsquare:5.880
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 55-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.304 | Rwp:7.600 | Rsquare:5.879
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 56-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.304 | Rwp:7.600 | Rsquare:5.879
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 57-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.304 | Rwp:7.599 | Rsquare:5.878
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 58-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.304 | Rwp:7.599 | Rsquare:5.878
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 59-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.303 | Rwp:7.599 | Rsquare:5.878
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 60-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.303 | Rwp:7.599 | Rsquare:5.877
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 61-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.303 | Rwp:7.598 | Rsquare:5.877
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 62-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.303 | Rwp:7.598 | Rsquare:5.876
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 63-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.303 | Rwp:7.598 | Rsquare:5.876
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 64-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.302 | Rwp:7.598 | Rsquare:5.876
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 65-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.302 | Rwp:7.597 | Rsquare:5.875
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 66-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.302 | Rwp:7.597 | Rsquare:5.875
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 67-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.302 | Rwp:7.597 | Rsquare:5.874
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 68-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.302 | Rwp:7.596 | Rsquare:5.874
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 69-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.393]
# Rp:4.301 | Rwp:7.596 | Rsquare:5.874
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 70-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.301 | Rwp:7.596 | Rsquare:5.873
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 71-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.301 | Rwp:7.596 | Rsquare:5.873
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 72-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.301 | Rwp:7.595 | Rsquare:5.872
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 73-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.301 | Rwp:7.595 | Rsquare:5.872
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 74-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.300 | Rwp:7.595 | Rsquare:5.871
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 75-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.300 | Rwp:7.594 | Rsquare:5.871
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 76-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.300 | Rwp:7.594 | Rsquare:5.870
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 77-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.300 | Rwp:7.594 | Rsquare:5.870
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 78-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.300 | Rwp:7.593 | Rsquare:5.869
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 79-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.299 | Rwp:7.593 | Rsquare:5.869
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 80-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.299 | Rwp:7.593 | Rsquare:5.868
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 81-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.299 | Rwp:7.592 | Rsquare:5.868
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 82-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.299 | Rwp:7.592 | Rsquare:5.867
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 83-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.299 | Rwp:7.592 | Rsquare:5.867
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 84-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.298 | Rwp:7.591 | Rsquare:5.866
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 85-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.298 | Rwp:7.591 | Rsquare:5.866
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 86-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.298 | Rwp:7.591 | Rsquare:5.865
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 87-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.298 | Rwp:7.590 | Rsquare:5.865
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 88-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.298 | Rwp:7.590 | Rsquare:5.864
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 89-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.297 | Rwp:7.590 | Rsquare:5.864
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 90-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.297 | Rwp:7.589 | Rsquare:5.863
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 91-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.297 | Rwp:7.589 | Rsquare:5.863
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 92-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.297 | Rwp:7.589 | Rsquare:5.862
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 93-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.297 | Rwp:7.588 | Rsquare:5.862
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 94-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.296 | Rwp:7.588 | Rsquare:5.861
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 95-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.296 | Rwp:7.588 | Rsquare:5.861
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 96-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.296 | Rwp:7.587 | Rsquare:5.860
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 97-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.296 | Rwp:7.587 | Rsquare:5.860
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 98-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.296 | Rwp:7.587 | Rsquare:5.859
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 99-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.295 | Rwp:7.586 | Rsquare:5.858
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 100-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.295 | Rwp:7.586 | Rsquare:5.858
#
#
# Under the central field approximation, the effective charge of Cu is: 25.71
# WPEM 101-th iteration
# ['Cu', '2p3/2', 932.594]
# ['Cu', '2p1/2', 952.392]
# Rp:4.295 | Rwp:7.586 | Rsquare:5.857
#
#
# After update the background :   Rp = 3.326 | Rwp = 7.176 | Rsquare = 5.464
# 101-th iterations, reach the maximum number of iteration steps.
#  Rp: 3.326
# Rwp: 7.176
#
#
# WPEM-XPS program running time :  0 hours 0 minute  5 second
# '0 hours 0 minute  5 second  '
