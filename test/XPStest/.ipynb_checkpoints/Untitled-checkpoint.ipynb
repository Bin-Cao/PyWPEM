# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2023-11-08 18:59:37  | Have a great day.
# ====================================================================================================

# %%
intensity_csv = pd.read_csv(r'int.csv',header=None )
var = WPEM.BackgroundFit(intensity_csv,bac_split=6,bac_num=200,Model='XPS',noise = 0.2,bac_var_type='multivariate gaussian')
# Out:
# /Users/jacob/Documents/GitHub/PyWPEM/Background/BacDeduct.py:293: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Intensity_mean, Intensity_dev = model.predict(angle[:, np.newaxis], return_std=True)

# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM


AtomIdentifier = [['Cu','2p3/2',932.9],['Cu','2p1/2',952.5],['Cu2','2p3/2',932.3],['Cu2','2p1/2',952.5]]

var = 2.

# The file name of non-background data (2theta-intensity data)
no_bac_intensity_file = "no_bac_intensity.csv" 
# The file name of raw/original data (2theta-intensity data)
original_file = "int.csv"  
# The file name of background data (2theta-intensity data)
bacground_file = "bac.csv"  



# Execute the model
WPEM.XPSfit(
    var, AtomIdentifier, no_bac_intensity_file, original_file, bacground_file, 
    bta = 0.90,iter_max = 2, asy_C = 0., energy_range=(920,960),InitializationEpoch=0 
    )
# Out:
# Started at Wed Nov  8 19:21:27 2023
#
# Initialization
# --------------------------------------------------------------------------------
#
#
# —————————— Initilize the parameters by WPEM ——————————
# Parameters of XPS are initialized has been completed
#
# Under the central field approximation, the effective charge of Cu is: 25.65
# Under the central field approximation, the effective charge of Cu2 is: 25.83
# WPEM 1-th iteration
# ['Cu', '2p3/2', 932.901]
# ['Cu', '2p1/2', 952.515]
# ['Cu2', '2p3/2', 932.342]
# ['Cu2', '2p1/2', 952.512]
# Rp:39.925 | Rwp:70.216 | Rsquare:188.877
#
#
# Under the central field approximation, the effective charge of Cu is: 25.65
# Under the central field approximation, the effective charge of Cu2 is: 25.83
# WPEM 2-th iteration
# ['Cu', '2p3/2', 932.899]
# ['Cu', '2p1/2', 952.513]
# ['Cu2', '2p3/2', 932.349]
# ['Cu2', '2p1/2', 952.519]
# Rp:40.303 | Rwp:71.541 | Rsquare:194.204
#
#
# Under the central field approximation, the effective charge of Cu is: 25.65
# Under the central field approximation, the effective charge of Cu2 is: 25.84
# WPEM 3-th iteration
# ['Cu', '2p3/2', 932.901]
# ['Cu', '2p1/2', 952.516]
# ['Cu2', '2p3/2', 932.341]
# ['Cu2', '2p1/2', 952.542]
# Rp:40.527 | Rwp:72.440 | Rsquare:198.060
#
#
# After update the background :   Rp = 40.527 | Rwp = 72.440 | Rsquare = 198.060
# 3-th iterations, reach the maximum number of iteration steps.
#  Rp: 40.527
# Rwp: 72.440
#
#
# WPEM-XPS program running time :  0 hours 0 minute  4 second
# '0 hours 0 minute  4 second  '
